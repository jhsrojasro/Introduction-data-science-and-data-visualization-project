# %%
# !apt install mongodb >log
# !service mongodb start
# Out:
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#  * Starting database mongodb
#    ...done.

# %%
# !mongo #Correr consola y crear base de datos con el comando: use ViinaDB;
# Out:
# MongoDB shell version v3.6.3
# connecting to: mongodb://127.0.0.1:27017
# MongoDB server version: 3.6.3
# Server has startup warnings:
# 2022-05-16T16:52:01.953+0000 I CONTROL  [initandlisten]
# 2022-05-16T16:52:01.953+0000 I CONTROL  [initandlisten] ** WARNING: Access control is not enabled for the database.
# 2022-05-16T16:52:01.953+0000 I CONTROL  [initandlisten] **          Read and write access to data and configuration is unrestricted.
# 2022-05-16T16:52:01.953+0000 I CONTROL  [initandlisten]
# > use viinaDB;use viinaDB;
# switched to db viinaDB
# > show dbs;show dbs;
# admin   0.000GB
# config  0.000GB
# local   0.000GB
# > 2022-05-16T17:02:18.286+0000 I CONTROL  [main] shutting down with code:0

# %%
from pymongo import MongoClient
client = MongoClient("mongodb://127.0.0.1:27017")

# %%
db = client['viinaDB']
#client.list_database_names() # ['admin', 'local']
#db.collection_names()

# %%
client.list_database_names() # ['admin', 'local']
# Out:
# ['admin', 'config', 'local']

# %%
db.PopulatedPlace.insert_one({})
db.ControlStatus.insert_one({})
db.Temporary.insert_one({})
db.Report.insert_one({})
db.Event.insert_one({})
populated_place_collection = db.PopulatedPlace
control_status_collection = db.ControlStatus
temporary_collection = db.Temporary
report_collection = db.Report
event_collection = db.Event
# Out:
# Collection(Database(MongoClient(host=['127.0.0.1:27017'], document_class=dict, tz_aware=False, connect=True), 'viinaDB'), 'collection_names')

# %%
populated_place_collection.drop()
control_status_collection.drop()
temporary_collection.drop()
report_collection.drop()
event_collection.drop()
#collection.insert_many(list(professor.values()))
